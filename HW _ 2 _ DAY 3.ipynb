# %%
ogrsayisi=int(input("Lütfen öğrenci sayısını giriniz:"))
isimler = [["" for k in range(2)]for c in range(ogrsayisi)]
puanlar = [[0 for l in range(3)]for d in range(ogrsayisi)]
ortalamalar= [0 for q in range(ogrsayisi)]
for i in range(ogrsayisi):
  print(i+1,". öğrenciye ait bilgileri giriniz.")
  isimler[i][0]=input("Öğrencinin Adını giriniz:")
  isimler[i][1]=input("Öğrencinin Soyadını giriniz:")
  puanlar[i][0]=int(input("Öğrencinin Vize notunu giriniz:"))
  puanlar[i][1]=int(input("Öğrencinin Final notunu giriniz:"))
  puanlar[i][2]=int(input("Öğrencinin Ev Ödevi notunu giriniz:"))
  ortalamalar[i]=int((puanlar[i][0]+puanlar[i][1]+puanlar[i][2])/3)
  info[i] ={isimler[i][0]:isimler[i][1],"VİZE NOTU:":puanlar[i][0],"Final:":puanlar[i][1],"Ev Ödevi:":puanlar[i][2],"Ortalama:":((puanlar[i][0]+puanlar[i][1]+puanlar[i][2])/3)}
  if en < ortalamalar[i]:
    en=ortalamalar[i]
    ogr_no=i
  else:
    continue
print("En yüksek puan alan öğrencimizin bilgileri :",info.get(ogr_no))
