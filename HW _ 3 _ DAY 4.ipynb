# %%
def prime_first(deger):
  print(deger," değeri 0-500 arasında olup ASALDIR.")

def prime_second(deger):
  print(deger," değeri 0-1000 arasında olup ASALDIR.")
say=0
for i in range(1,1000+1):
  for j in range (2,i): 
    if (i % j) == 0:
      break
  else:
     if i <= 500:
       prime_first(i)
     else:
       prime_second(i)
